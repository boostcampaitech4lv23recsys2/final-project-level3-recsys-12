# %%
import os
import pandas as pd

# %%
house_code = pd.read_csv("/Users/kth/Documents/team_project/crawling/data/house_code.csv")
house_df = pd.read_csv("/Users/kth/Documents/team_project/crawling/data/house.csv")

# %%
left = set(house_code.house.values)-set(house_df.house.values)

# %%
len(left)
# Out:
# 5373

# %%
len(os.listdir("/Users/kth/Documents/team_project/crawling/data/hi_interaction"))
# Out:
# 10626

# %%
df = pd.concat(list(map(lambda x:pd.read_csv(f"/Users/kth/Documents/team_project/crawling/data/hi_interaction/{x}"),os.listdir("/Users/kth/Documents/team_project/crawling/data/hi_interaction"))))

# %%
df.nunique()
# Out:
# house      9892
# item     146096
# dtype: int64

# %%
df_hc = pd.concat(list(map(lambda x:pd.read_csv(f"/Users/kth/Documents/team_project/crawling/data/hc_interaction/{x}"),os.listdir("/Users/kth/Documents/team_project/crawling/data/hc_interaction"))))

# %%
df_hc.nunique()
# Out:
# house     10435
# card     404716
# dtype: int64

# %%
407529/(9892*146096)
# Out:
# 0.0002819915441604506

# %%
house_code = pd.read_csv("data/house_code.csv")

# %%
import matplotlib.pyplot as plt

# %%
df.house.value_counts().hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
house_df
# Out:
#        house   공간   평수      작업    분야         가족형태          지역  \
# 0         76  아파트  24평  셀프•DIY  리모델링        싱글라이프   서울특별시 강동구
# 1         78  아파트  37평     전문가  리모델링  취학 자녀가 있는 집   서울특별시 서초구
# 2         79  아파트  24평  셀프•DIY  리모델링     아기가 있는 집   서울특별시 구로구
# 3         80  아파트  22평     전문가  리모델링         신혼부부     경기도 성남시
# 4         81  아파트  32평  셀프•DIY  리모델링          NaN   서울특별시 노원구
# ...      ...  ...  ...     ...   ...          ...         ...
# 5252  134583  아파트  33평     전문가  리모델링         신혼부부  서울특별시 영등포구
# 5253  134672  아파트  21평     전문가  리모델링        싱글라이프     경기도 성남시
# 5254  134896  아파트  34평     전문가  리모델링  취학 자녀가 있는 집   부산광역시 연제구
# 5255  134896  아파트  34평     전문가  리모델링  취학 자녀가 있는 집   부산광역시 연제구
# 5256  134946  아파트  31평     전문가  리모델링        싱글라이프         NaN
#
#                     스타일   기간                 예산  \
# 0                    모던  NaN                NaN
# 1                    모던  NaN  4,000만원 ~ 5,000만원
# 2                    모던  NaN                NaN
# ...

# %%
set(house_code.house.values)-set(house_df.house.values)
# Out:
# {132458,
#  132464,
#  132488,
#  132519,
#  132522,
#  132525,
#  132580,
#  99983,
#  132751,
#  132799,
#  132876,
#  132992,
#  133027,
#  133033,
#  133037,
#  133104,
#  133189,
#  133192,
#  133196,
#  133199,
#  67699,
#  133774,
#  133792,
#  133796,
#  101193,
#  68439,
#  101219,
#  101224,
#  68581,
#  68582,
#  68584,
#  68596,
#  134133,
#  68600,
#  101427,
#  101441,
#  101468,
#  101469,
#  68702,
#  101478,
#  101488,
#  101493,
#  35963,
#  68747,
#  68847,
#  68887,
#  68889,
#  36130,
#  36142,
#  134446,
#  36149,
#  101934,
#  101935,
#  36400,
#  69210,
#  102093,
#  102878,
#  37344,
#  74866,
#  107801,
#  43735,
#  43737,
#  10969,
#  43738,
#  109287,
#  43754,
#  76527,
#  10995,
#  11009,
#  11010,
#  43779,
#  11014,
#  11018,
#  11019,
#  11023,
#  11024,
#  76566,
#  11031,
#  43804,
#  43805,
#  43806,
#  43807,
#  43808,
#  109347,
#  43812,
#  11056,
#  11060,
#  43829,
#  43836,
#  43838,
#  109375,
#  109376,
#  43843,
#  43849,
#  11082,
# ...

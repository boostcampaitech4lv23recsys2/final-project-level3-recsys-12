# %%
import pandas as pd

# %%
item = pd.read_csv("../crawling/output/item.tsv", sep="\t")
train = pd.read_csv("../backend/data/train.tsv", sep="\t")
item.drop(index=item[item.rating == 'ņĀÉ 5.0ņĀ'].index, inplace=True)
item.drop(index=item[item.rating == 'м†Р 4.8м†'].index, inplace=True)
item.review = item.review.astype(int)
item.rating = item.rating.astype(float)
# Out:
# /tmp/ipykernel_9082/440698230.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   item = pd.read_csv("../crawling/output/item.tsv", sep="\t")

# %%
# import webbrowser
# import time

# for a in (item[item.item.isin(top)].image):
#     webbrowser.open(a)

# %%
train.item.value_counts()
# Out:
# 204619     848
# 438844     552
# 354736     461
# 176428     424
# 313120     336
#           ...
# 929433       1
# 74894        1
# 737824       1
# 317660       1
# 1825409      1
# Name: item, Length: 88935, dtype: int64

# %%
import matplotlib.pyplot as plt

item_counts = train['item'].value_counts()
plt.hist(item_counts, bins=50, log=True, orientation='horizontal')
plt.ylabel('Number of Interactions')
plt.xlabel('Number of Items')
plt.title('Interactions per Item (Log Scale)')
plt.show()

item_counts = train['item'].value_counts()
plt.hist(item_counts, bins=50, log=False, orientation='horizontal')
plt.ylabel('Number of Interactions')
plt.xlabel('Number of Items')
plt.title('Interactions per Item (Original Scale)')
plt.show()

# %%
train_moviedata = pd.read_csv("../crawling/output/train_moviedata.csv")

# %%
import matplotlib.pyplot as plt

item_counts = train_moviedata['item'].value_counts()
plt.hist(item_counts, bins=50, log=True, orientation='horizontal')
plt.ylabel('Number of Interactions')
plt.xlabel('Number of Items')
plt.title('Interactions per Item (Log Scale)')
plt.show()

item_counts = train_moviedata['item'].value_counts()
plt.hist(item_counts, bins=50, log=False, orientation='horizontal')
plt.ylabel('Number of Interactions')
plt.xlabel('Number of Items')
plt.title('Interactions per Item (Log Scale)')
plt.show()

# %%
item.drop(index=item[item.rating == 'ņĀÉ 5.0ņĀ'].index, inplace=True)
item.drop(index=item[item.rating == 'м†Р 4.8м†'].index, inplace=True)
item.review = item.review.astype(int)
item.rating = item.rating.astype(float)

# %%
from sklearn.preprocessing import *

mm = MinMaxScaler()
item_review = item.review.to_frame()
item["mm_review"] = mm.fit_transform(item_review).squeeze(1)

import matplotlib.pyplot as plt

plt.hist(item["review"], bins=50, edgecolor='black')
plt.xlabel("Scaled Review")
plt.ylabel("Frequency")
plt.title("NO Scaler Transformation")
plt.show()

plt.hist(item["mm_review"], bins=50, edgecolor='black')
plt.xlabel("Scaled Review")
plt.ylabel("Frequency")
plt.title("MinMax Scaler Transformation")
plt.show()

# %%
type(mm.fit_transform(item_review))
# Out:
# numpy.ndarray

# %%
mm.fit_transform(item_review).reshape(-1)
# Out:
# array([0.06706707, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ])

# %%
item = item[(item.rating > 0) & (item.review > 200)]

# %%
from sklearn.preprocessing import *

mm = MinMaxScaler()
item_review = item.review.to_frame()
item["mm_review"] = mm.fit_transform(item_review).squeeze(1)

import matplotlib.pyplot as plt

plt.hist(item["review"], bins=50, edgecolor='black')
plt.xlabel("Scaled Review")
plt.ylabel("Frequency")
plt.title("NO Scaler Transformation")
plt.show()

plt.hist(item["mm_review"], bins=50, edgecolor='black')
plt.xlabel("Scaled Review")
plt.ylabel("Frequency")
plt.title("MinMax Scaler Transformation")
plt.show()

# %%
from sklearn.preprocessing import *

mm = RobustScaler()
item_review = item.review.to_frame()
item["mm_review"] = mm.fit_transform(item_review).squeeze(1)

import matplotlib.pyplot as plt

plt.hist(item["review"], bins=50, edgecolor='black')
plt.xlabel("Scaled Review")
plt.ylabel("Frequency")
plt.title("NO Scaler Transformation")
plt.show()

plt.hist(item["mm_review"], bins=50, edgecolor='black')
plt.xlabel("Scaled Review")
plt.ylabel("Frequency")
plt.title("Robust Scaler Transformation")
plt.show()

# %%
from sklearn.preprocessing import *

mm = StandardScaler()
item_review = item.review.to_frame()
item["mm_review"] = mm.fit_transform(item_review).squeeze(1)

import matplotlib.pyplot as plt

plt.hist(item["review"], bins=50, edgecolor='black')
plt.xlabel("Scaled Review")
plt.ylabel("Frequency")
plt.title("NO Scaler Transformation")
plt.show()

plt.hist(item["mm_review"], bins=50, edgecolor='black')
plt.xlabel("Scaled Review")
plt.ylabel("Frequency")
plt.title("Standard Scaler Transformation")
plt.show()

# %%
from sklearn.preprocessing import *

mm = Normalizer()
item_review = item.review.to_frame()
item["mm_review"] = mm.fit_transform(item_review).squeeze(1)

import matplotlib.pyplot as plt

plt.hist(item["review"], bins=50, edgecolor='black')
plt.xlabel("Scaled Review")
plt.ylabel("Frequency")
plt.title("NO Scaler Transformation")
plt.show()

plt.hist(item["mm_review"], bins=50, edgecolor='black')
plt.xlabel("Scaled Review")
plt.ylabel("Frequency")
plt.title("Normalizer Scaler Transformation")
plt.show()

# %%
from sklearn.preprocessing import *

mm = StandardScaler()
item_rating = item.rating.to_frame()
item["mm_rating"] = mm.fit_transform(item_rating).squeeze(1)

import matplotlib.pyplot as plt

plt.hist(item["rating"], bins=50, edgecolor='black')
plt.xlabel("Scaled Rating")
plt.ylabel("Frequency")
plt.title("NO Scaler Transformation")
plt.show()

plt.hist(item["mm_rating"], bins=50, edgecolor='black')
plt.xlabel("Scaled Rating")
plt.ylabel("Frequency")
plt.title("Standard Scaler Transformation")
plt.show()

# %%
from sklearn.preprocessing import *

mm = MinMaxScaler()
item_rating = item.rating.to_frame()
item["mm_rating"] = mm.fit_transform(item_rating).squeeze(1)

import matplotlib.pyplot as plt

plt.hist(item["rating"], bins=50, edgecolor='black')
plt.xlabel("Scaled Rating")
plt.ylabel("Frequency")
plt.title("NO Scaler Transformation")
plt.show()

plt.hist(item["mm_rating"], bins=50, edgecolor='black')
plt.xlabel("Scaled Rating")
plt.ylabel("Frequency")
plt.title("MinMax Scaler Transformation")
plt.show()

# %%
from sklearn.preprocessing import *

mm = RobustScaler()
item_rating = item.rating.to_frame()
item["mm_rating"] = mm.fit_transform(item_rating).squeeze(1)

import matplotlib.pyplot as plt

plt.hist(item["rating"], bins=50, edgecolor='black')
plt.xlabel("Scaled Rating")
plt.ylabel("Frequency")
plt.title("NO Scaler Transformation")
plt.show()

plt.hist(item["mm_rating"], bins=50, edgecolor='black')
plt.xlabel("Scaled Rating")
plt.ylabel("Frequency")
plt.title("Robust Scaler Transformation")
plt.show()

# %%
from sklearn.preprocessing import *

mm = Normalizer()
item_rating = item.rating.to_frame()
item["mm_rating"] = mm.fit_transform(item_rating).squeeze(1)

import matplotlib.pyplot as plt

plt.hist(item["rating"], bins=50, edgecolor='black')
plt.xlabel("Scaled Rating")
plt.ylabel("Frequency")
plt.title("NO Scaler Transformation")
plt.show()

plt.hist(item["mm_rating"], bins=50, edgecolor='black')
plt.xlabel("Scaled Rating")
plt.ylabel("Frequency")
plt.title("Noramlizer Scaler Transformation")
plt.show()

# %%
import torch
torch.as_tensor(item.rating.to_numpy()).float()
# Out:
# tensor([4.7000, 4.6000, 4.6000,  ..., 4.7000, 4.8000, 4.7000])

# %%
train
# Out:
#          house     item
# 0          318       55
# 1          318     1490
# 2          318     2256
# 3          318     2257
# 4          318     2258
# ...        ...      ...
# 258408  135539  1614645
# 258409  135539  1647884
# 258410  135539  1663802
# 258411  135539  1743484
# 258412  135539  1825409
#
# [258413 rows x 2 columns]

# %%
t = [33050, 441917, 212240, 876149, 30484, 41712, 853362, 30495, 33081, 30504, 33086, 1152, 38925, 33089, 30528, 639470, 38945, 30532, 38947, 38951, 563197, 38953, 26926, 38963, 909706, 909717, 315076, 544635, 1320247, 36594, 48152, 768611, 386975, 176428, 14395, 61315, 1092386, 225061, 387093, 387106, 33580, 748742, 123463, 310209, 1321586, 33735, 280948, 135891, 1055509, 303875, 18446, 131781, 1325, 1036195, 131838, 31085, 33852, 68422, 680807, 481893, 537573, 225482, 213839, 225484, 310706, 172680, 42545, 136673, 1450530, 641627, 181848, 88674, 34103, 414026, 1451760, 31336, 128435, 691069, 735254, 414449, 24302, 109802, 348334, 1026007, 1399771, 69056, 1154849, 148603, 2699, 354736, 182232, 226085, 567071, 89085, 34624, 547677, 624613, 155409, 451187, 1071454, 246017, 11721, 11727, 97064, 11729, 451232, 37307, 11733, 306151, 11738, 11731, 429064, 11750, 823099, 173544, 363774, 701233, 1072212, 1072221, 752541, 2864, 1006410, 19486, 79841, 1006485, 438844, 237045, 149087, 1171337, 237059, 1157216, 1060151, 485244, 1248819, 19562, 1028902, 773248, 1060535, 938129, 65810, 814245, 31965, 251331, 981458, 1084568, 58467, 312920, 15735, 872870, 702583, 15833, 169066, 605321, 49639, 12589, 1158159, 585078, 237554, 313120, 753989, 682, 32125, 313203, 169244, 153526, 705, 16201, 540903, 745550, 138894, 204610, 71092, 29275, 204619, 995584, 995602, 995590, 204611, 313488, 336837, 204615, 32199, 13082, 158184, 46969, 826577, 1235652, 328613, 307885, 1020795, 252272, 874418, 264565, 1160354, 170039, 36011, 550989, 675895, 884208, 83763, 130321, 308338, 117522, 38483, 13236, 954778, 1076749, 153835, 766950, 224146, 1414013, 13495, 13505, 13524, 731281, 747576, 17023, 38044, 30335, 1276387, 1276391]

# %%
item[(item.item.isin(t)) & (item.review > 0)]
# Out:
#           item                      category  rating  review       price  \
# 3824     11727                 가구|서랍·수납장|수납장     4.6     389         NaN
# 3826     11729                   가구|의자|스툴·벤치     4.7     610         NaN
# 3829     11733                   가구|의자|스툴·벤치     4.6     749      9,000원
# 3963     13082              데코·식물|시계|알람·탁상시계     4.8     233         NaN
# 4040     13236                  패브릭|쿠션·방석|쿠션     4.7     545         NaN
# 4066     13505                  가구|의자|인테리어의자     4.7     616     22,900원
# 4068     13524              패브릭|주방패브릭|행주·티타월     4.7     863         NaN
# 4724     18446          데코·식물|플라워·식물|식물|다육식물     4.7     486         NaN
# 4883     19486     데코·식물|디퓨저·캔들|캔들홀더·워머|캔들홀더     4.7     371         NaN
# 5318     24302         데코·식물|플라워·식물|화병·화분|화분     4.6     641         NaN
# 5668     26926       주방용품|보관·용기·도시락|밀폐용기·반찬통     4.5     681     55,200원
# 5989     29275           가구|테이블·식탁·책상|사이드테이블     4.7     525     17,600원
# 6162     30504                  가구|의자|인테리어의자     4.6     301     61,000원
# 6679     33089           가구|테이블·식탁·책상|사이드테이블     4.7     634         NaN
# 7407     37307           가구|테이블·식탁·책상|사이드테이블     4.7     999     47,900원
# 8204     41712                   가구|의자|스툴·벤치     4.5     356     97,000원
# 9090     46969   가전·디지털|주방가전|토스터·와플메이커|일반토스터     4.8     610    178,000원
# 9277     48152                 가구|서랍·수납장|수납장     4.7     371         NaN
# 10829    61315          가구|테이블·식탁·책상|책상|일반책상     4.5     351         NaN
# 12564    79841  가전·디지털|음향가전|스피커|블루투스·인공지능스피커     4.8     690         NaN
# 14577    97064         데코·식물|플라워·식물|화병·화분|화분     4.7     261         NaN
# 18110   128435                  가구|서랍·수납장|협탁     4.6     328    169,000원
# 18550   131781                       조명|장스탠드     4.9     464         NaN
# 19056   135891      가구|테이블·식탁·책상|식탁|식탁·입식테이블     4.5     656    535,000원
# 23114   176428              조명|무드등·장식조명|간접조명     4.8     883      8,000원
# 23767   182232                 가구|서랍·수납장|수납장     4.8     266         NaN
# 25960   204611             가전·디지털|계절가전|공기청정기     4.8     274    749,000원
# 26772   213839             가전·디지털|계절가전|공기청정기     4.6     477    299,000원
# 27798   225484           데코·식물|인테리어소품|모빌·가랜드     4.7     395     82,500원
# 27864   226085               가구|선반|벽선반|무지주선반     4.7     278         NaN
# 29003   237554  주방용품|보관·용기·도시락|쌀통·브레드박스·디스펜서     4.7     244     24,900원
# 29932   246017             가구|진열장·책장|진열장·장식장     4.5     521         NaN
# 34698   307885              조명|무드등·장식조명|간접조명     4.8     378      6,000원
# 49293   537573                   가구|의자|스툴·벤치     4.7     500         NaN
# 49717   544635           조명|무드등·장식조명|무드등·수유등     4.9     229         NaN
# 50086   550989     가전·디지털|주방가전|커피메이커·머신|커피머신     4.9     531    299,000원
# 58856   731281        가전·디지털|TV|189cm~(75"~)     4.8     401  3,392,000원
# 59749   745550       가전·디지털|주방가전|오븐·전자레인지|오븐     4.8     280    999,000원
# 59886   747576             가전·디지털|냉장고|양문형냉장고     4.9     647  2,890,000원
# 60239   753989               가전·디지털|주방가전|정수기     4.9     434  1,299,000원
# 60989   768611   가전·디지털|TV|164~188cm(65~74")     4.9     556  1,700,000원
# 61225   773248               가구|선반|벽선반|무지주선반     4.6     269     19,500원
# 63276   814245                       조명|단스탠드     4.8     493    270,000원
# 65941   874418     데코·식물|디퓨저·캔들|캔들홀더·워머|캔들홀더     4.8     366     61,000원
# 66055   876149   가전·디지털|주방가전|식기세척기·건조기|식기세척기     4.9     278  1,490,000원
# 73001  1028902                       조명|단스탠드     4.7     332    220,000원
# 73336  1036195             가전·디지털|냉장고|양문형냉장고     4.9     336         NaN
# 75856  1092386       가전·디지털|주방가전|오븐·전자레인지|오븐     4.9     273    690,000원
# 78233  1160354   가전·디지털|주방가전|식기세척기·건조기|식기세척기     4.9     220  1,490,000원
# 81190  1248819     가전·디지털|주방가전|가스레인지·인덕션|인덕션     4.9     303  1,390,000원
# 85147  1450530             가전·디지털|냉장고|양문형냉장고     4.9     276  2,800,000원
# 85169  1451760     가전·디지털|주방가전|가스레인지·인덕션|인덕션     4.9     425  1,590,000원
#
#                                                    title   seller  \
# 3824                                         PS 캐비넷 수납장      이케아
# 3826                                   FROSTA 스툴 3colors     이케아
# 3829                                       MARIUS 디자인 스툴     이케아
# 3963            친환경 LED 나무알람시계 4종 Real Wooden Clock 리얼우드     무아스
# 4040                          테마 레터링 쿠션/방석(단품&세트) 14종 택1     아이르
# 4066                                     ADDE 체어 4colors     이케아
# 4068                                             ELLY 행주     이케아
# 4724                              공기정화 / 전자파차단 미니 스투키 4종    피플랜트
# 4883                           ROTERA 미니 양초 랜턴 4colors       이케아
# 5318                         내츄럴 해초바구니(왕골 항아리바구니) 12type     꾸미까
# 5668                                    NEW 시리얼 디스펜서 17종     제브로
# 5989                                      GLADOM 트레이 테이블     이케아
# 6162                                       헤이 체어 7colors   체어팩토리
# 6679                                   NETUD 원목 수납테이블 2종     마켓비
# 7407                                         메이저 사이드 테이블    소프시스
# 8204                               모니카 니트스툴/푸프스툴 6colors    아카시아
# 9090                                 아이코나 전기토스터 CTOV2003     드롱기
# 9277                                  FILMON 시리즈 3colors     마켓비
# 10829                         베이직 책상 40 입식/좌식 22type\t\t    블루밍홈
# 12564                        공식국내배송 액톤2 블루투스 스피커 2colors      마샬
# 14577                                 독일 토분 바솔트 앤티크 그래니트   밍이네가든
# 18110                           킨포/알렉스 2단 550 협탁 5colors   아이엔지홈
# 18550                    (안전포장) LERSTA 레르스타 장스탠드_3colors     이케아
# 19056                               [할인쿠폰] 피카 확장형 4인 테이블    오투가구
# 23114                           LED T5 간접조명 라인조명_6colors    참라이팅
# 23767                        알렉스 1200 높은 수납장 ALEX 3color   아이엔지홈
# 25960                        더 퓨어 공기청정기 2colors 60㎡ 18평형     발뮤다
# 26772                                   [해외] 미에어2S 공기청정기     샤오미
# 27798                 FLENSTED MOBILES 모빌 - 미래 블랙 FUTURA   플렌스테드
# 27864                                     MOSSLANDA 액자선반     이케아
# 29003                                    틴 라이스박스/쌀통+계량컵      키펙스
# 29932                                      브릭나인 인테리어 벽난로    브릭나인
# 34698                     LED T5 형광등 SSEN_4sizes/3colors   공간LED
# 49293                                     BEKVAM 베크벰스텝스툴     이케아
# 49717                       미나 LED 미니 버섯램프_LH60 12colors      렉슨
# 50086       [공식인증] 네스프레소 버츄오플러스 블랙/화이트/실버/매트블랙 + 캡슐12개포함   네스프레소
# 58856        삼세페 삼성공식인증몰 QLED 4K  TV KQ75QA65AFXKR 189cm    삼성전자
# 59749                     LG 디오스 광파오븐 오브제컬렉션 ML32EW1 32L    LG전자
# 59886                    비스포크 키친핏 4도어 냉장고 RF60B91C3AP 코타    삼성전자
# 60239             삼성 비스포크 직수형 냉/온 정수기 RWP71411AAP 빌트인정수기    삼성전자
# 60989  [연휴특가/102만] 삼성 공식 UHD TV  KU65UA8070FXKR 163cm...    삼성전자
# 61225                             인테리어 무지주 벽선반 30T 4size  우드리퍼블릭
# 63276               신상 레드 컬러 입고! [해외] 네시노 테이블 램프 3colors   아르테미데
# 65941                               빈티지 무드의 나무 소품, 벽거울촛대  클라우드살몬
# 66055               비스포크 12인용 열풍건조 식기세척기 DW60A8355FG 인증점    삼성전자
# 73001                          [해외]네시노 테이블 램프 오렌지/화이트/레드   아르테미데
# 73336              LG 디오스 오브제컬렉션 냉장고 M872AAA031 870L 조합형    LG전자
# 75856                 비스포크 큐커 전기오븐 MO22A7797CWR 22리터 인증점    삼성전자
# 78233           [오늘의딜] LG 디오스 식기세척기 오브제컬렉션 DUBJ2EAL 12인용    LG전자
# 81190    [혜택가87만원대]비스포크 인덕션 NZ63B8708XH 3구 전기레인지 빌트인 화이트    삼성전자
# 85147                  LG 디오스 노크온 오브제컬렉션 T873MEE312 870L    LG전자
# 85169  [오늘의딜/카드혜택 72만원대]삼성전자 비스포크 3구 인덕션 화이트 NZ63B650...    삼성전자
#
#       discount_rate                                              image  \
# 3824            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 3826            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 3829             1%  https://image.ohou.se/i/bucketplace-v2-develop...
# 3963            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 4040            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 4066            19%  https://image.ohou.se/i/bucketplace-v2-develop...
# 4068            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 4724            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 4883            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 5318            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 5668            50%  https://image.ohou.se/i/bucketplace-v2-develop...
# 5989             4%  https://image.ohou.se/i/bucketplace-v2-develop...
# 6162            35%  https://image.ohou.se/i/bucketplace-v2-develop...
# 6679            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 7407            37%  https://image.ohou.se/i/bucketplace-v2-develop...
# 8204            59%  https://image.ohou.se/i/bucketplace-v2-develop...
# 9090            16%  https://image.ohou.se/i/bucketplace-v2-develop...
# 9277            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 10829           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 12564           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 14577           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 18110           55%  https://image.ohou.se/i/bucketplace-v2-develop...
# 18550           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 19056           22%  https://image.ohou.se/i/bucketplace-v2-develop...
# 23114           20%  https://image.ohou.se/i/bucketplace-v2-develop...
# 23767           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 25960           20%  https://image.ohou.se/i/bucketplace-v2-develop...
# 26772           41%  https://image.ohou.se/i/bucketplace-v2-develop...
# 27798           17%  https://image.ohou.se/i/bucketplace-v2-develop...
# 27864           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 29003           20%  https://image.ohou.se/i/bucketplace-v2-develop...
# 29932           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 34698           35%  https://image.ohou.se/i/bucketplace-v2-develop...
# 49293           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 49717           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 50086           33%  https://image.ohou.se/i/bucketplace-v2-develop...
# 58856           46%  https://image.ohou.se/i/bucketplace-v2-develop...
# 59749           36%  https://image.ohou.se/i/bucketplace-v2-develop...
# 59886           26%  https://image.ohou.se/i/bucketplace-v2-develop...
# 60239           22%  https://image.ohou.se/i/bucketplace-v2-develop...
# 60989           36%  https://image.ohou.se/i/bucketplace-v2-develop...
# 61225           25%  https://image.ohou.se/i/bucketplace-v2-develop...
# 63276           35%  https://image.ohou.se/i/bucketplace-v2-develop...
# 65941            2%  https://image.ohou.se/i/bucketplace-v2-develop...
# 66055           26%  https://image.ohou.se/i/bucketplace-v2-develop...
# 73001           22%  https://image.ohou.se/i/bucketplace-v2-develop...
# 73336           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 75856           34%  https://image.ohou.se/i/bucketplace-v2-develop...
# 78233           33%  https://image.ohou.se/i/bucketplace-v2-develop...
# 81190           33%  https://image.ohou.se/i/bucketplace-v2-develop...
# 85147           32%  https://image.ohou.se/i/bucketplace-v2-develop...
# 85169           52%  https://image.ohou.se/i/bucketplace-v2-develop...
#
#       available_product predict_price  \
# 3824                NaN          정보없음
# 3826                미입점        14,100
# 3829                NaN          정보없음
# 3963                미입점          정보없음
# 4040                미입점          정보없음
# 4066                NaN          정보없음
# 4068                NaN          정보없음
# 4724                미입점          정보없음
# 4883                NaN          정보없음
# 5318                미입점          정보없음
# 5668                NaN          정보없음
# 5989                NaN          정보없음
# 6162                NaN          정보없음
# 6679                미입점          정보없음
# 7407                NaN          정보없음
# 8204                NaN          정보없음
# 9090                NaN          정보없음
# 9277                미입점          정보없음
# 10829               미입점          정보없음
# 12564               NaN          정보없음
# 14577               미입점          정보없음
# 18110               NaN          정보없음
# 18550               미입점        19,900
# 19056               NaN          정보없음
# 23114               NaN          정보없음
# 23767               미입점       124,000
# 25960               NaN          정보없음
# 26772               NaN          정보없음
# 27798               NaN          정보없음
# 27864               NaN          정보없음
# 29003               NaN          정보없음
# 29932               NaN          정보없음
# 34698               NaN          정보없음
# 49293               NaN          정보없음
# 49717               미입점        39,900
# 50086               NaN          정보없음
# 58856               NaN          정보없음
# 59749               NaN          정보없음
# 59886               NaN          정보없음
# 60239               NaN          정보없음
# 60989               NaN          정보없음
# 61225               NaN          정보없음
# 63276               NaN          정보없음
# 65941               NaN          정보없음
# 66055               NaN          정보없음
# 73001               NaN          정보없음
# 73336               NaN          정보없음
# 75856               NaN          정보없음
# 78233               NaN          정보없음
# 81190               NaN          정보없음
# 85147               NaN          정보없음
# 85169               NaN          정보없음
#
#                               preprocessed_title  \
# 3824                                   ps 캐비넷 수납
# 3826                                   frosta 스툴
# 3829                               marius 디자인 스툴
# 3963   친환경 led 나무 알람시계 종 real wooden clock 리얼 우드
# 4040                      테마 레터 링 쿠션 방석 품 세트 종 택
# 4066                                     adde 체어
# 4068                                     elly 행주
# 4724                       공기 정화 전자파 차단 미니 스투키 종
# 4883                             rotera 미니 양초 랜턴
# 5318                       내츄럴 해초 바구니 왕골 항아리 바구니
# 5668                             new 시리얼 디 스펜서 종
# 5989                             gladom 트 레이 테이블
# 6162                                       헤이 체어
# 6679                           netud 원목 수납 테이블 종
# 7407                                 메이저 사이드 테이블
# 8204                              모니카 니트 스툴 푸프스툴
# 9090                           나 전기 토스터 ctov2003
# 9277                                  filmon 시리즈
# 10829                              베이직 책상 40 입 좌
# 12564                       공식 국내 배송 액톤 블루투스 스피커
# 14577                        독일 토분 바 솔트 앤티크 그래니트
# 18110                            킨포 알렉스 단 550 협탁
# 18550                         lersta 레르 스타 장 스탠드
# 19056                                피카 확장 인 테이블
# 23114                         led t5 간접 조명 라인 조명
# 23767                           알렉스 1200 수납 alex
# 25960                           더 퓨어 공기청정기 60 평형
# 26772                                   에어 공기청정기
# 27798           flensted mobiles 모빌 미래 블랙 futura
# 27864                            mosslanda 액자 선반
# 29003                            틴 라이스 박스 쌀통 계량컵
# 29932                             브릭 나인 인테리어 벽난로
# 34698                     led t5 형광등 ssen 4sizes
# 49293                            bekvam 베크 스텝스 툴
# 49717                            미나 led 미니 버섯 램프
# 50086       네스프레소 버츄 플러스 블랙 화이트 실버 매트 블랙 캡슐 개 포함
# 58856              페 공식 인증 qled tv kq75qa65afxkr
# 59749                lg 디오스 광파 오븐 오브 컬렉션 ml32ew1
# 59886           비 스포크 키친 핏 도어 냉장고 rf60b91c3ap 코타
# 60239   삼성 비 스포크 직 수형 냉 온 정수기 rwp71411aap 빌트 정수기
# 60989             삼성 공식 uhd tv ku65ua8070fxkr 65
# 61225                             인테리어 무 지주 벽 선반
# 63276                       신상 레드 컬러 해외 노 테이블 램프
# 65941                        빈티 무드 나무 소품 벽 거울 촛대
# 66055      비 스포크 인용 열풍 건조 식기세척기 dw60a8355fg 인증 점
# 73001                        노 테이블 램프 오렌지 화이트 레드
# 73336           lg 디오스 오브 컬렉션 냉장고 m872aaa031 조합형
# 75856         비 스포크 큐 전기 오븐 mo22a7797cwr 리터 인증 점
# 78233            lg 디오스 식기세척기 오브 컬렉션 dubj2eal 인용
# 81190       비 스포크 인덕션 nz63b8708xh 구 전기레인지 빌트 화이트
# 85147              lg 디오스 노크 온 오브 컬렉션 t873mee312
# 85169          삼성 전자 비 스포크 구 인덕션 화이트 nz63b6502xh
#
#                                          similarity_list  cluster_id  \
# 3824                                                  []         539
# 3826                                                  []       11856
# 3829   [['marius 디자인 스툴', 'marius 스툴', 149202, 0.8181...         541
# 3963                                                  []       11945
# 4040                                                  []       11992
# 4066                                                  []       12007
# 4068         [['elly 행주', 'elly 행주 가지 색상', 190204, 0.7]]       12008
# 4724                                                  []       12488
# 4883                                                  []         726
# 5318                                                  []       12934
# 5668   [['new 시리얼 디 스펜서 종', 'new 헤일리 시리얼 디 스펜서', 2811...         829
# 5989   [['gladom 트 레이 테이블', 'gladom 트 레이 테이블', 157523...         877
# 6162   [['헤이 체어', '헤이베 체어 색', 1229926, 0.769230769230...       13518
# 6679                                                  []       13903
# 7407                                                  []        1095
# 8204                                                  []       15048
# 9090   [['나 전기 토스터 ctov2003', '나 클래식 토스터 기 cto2003', ...        1303
# 9277                                                  []       15882
# 10829                                                 []        1545
# 12564                                                 []       18363
# 14577                                                 []       19928
# 18110                                                 []       22625
# 18550  [['lersta 레르 스타 장 스탠드', 'lersta 레르 스타 플로 스탠드',...        2508
# 19056  [['피카 확장 인 테이블', '피카 확장 테이블', 25185, 0.9], ['피...         795
# 23114                                                 []        2490
# 23767  [['알렉스 1200 수납 alex', '알렉스 1200 수납 alex 화이트', ...        3178
# 25960                                                 []       28271
# 26772  [['에어 공기청정기', '에어 공기청정기 한글 판', 215478, 0.76190...        1449
# 27798  [['flensted mobiles 모빌 미래 블랙 futura', 'flenste...        3595
# 27864                                                 []        2818
# 29003                                                 []       30570
# 29932                                                 []       31262
# 34698                                                 []       34646
# 49293  [['bekvam 베크 스텝스 툴', 'bekvam 베크 원목 스텝스 툴 계단 스툴...        2043
# 49717                                                 []       44337
# 50086                                                 []       44545
# 58856  [['페 공식 인증 qled tv kq75qa65afxkr', '페 공식 인증 삼성...        6905
# 59749  [['lg 디오스 광파 오븐 오브 컬렉션 ml32ew1', 'lg 디오스 광파 오븐...        6999
# 59886  [['비 스포크 키친 핏 도어 냉장고 rf60b91c3ap 코타', '비 스포크 키...        4263
# 60239  [['삼성 비 스포크 직 수형 냉 온 정수기 rwp71411aap 빌트 정수기', ...        7039
# 60989                                                 []       51946
# 61225  [['인테리어 무 지주 벽 선반', '인테리어 무 지주 선반 거실 벽 선반 종 택'...         612
# 63276                                                 []       53499
# 65941                                                 []       55373
# 66055                                                 []       55459
# 73001  [['노 테이블 램프 오렌지 화이트 레드', '노 테이블 램프 조명 화이트', 79...       60441
# 73336  [['lg 디오스 오브 컬렉션 냉장고 m872aaa031 조합형', 'lg 디오스 ...        8010
# 75856                                                 []        8194
# 78233  [['lg 디오스 식기세척기 오브 컬렉션 dubj2eal 인용', 'lg 디오스 식...        6757
# 81190  [['비 스포크 인덕션 nz63b8708xh 구 전기레인지 빌트 화이트', '비 스...       66431
# 85147  [['lg 디오스 노크 온 오브 컬렉션 t873mee312', 'lg 디오스 베이직...        8629
# 85169                                                 []       69337
#
#        mm_review  mm_rating
# 3824         1.0        1.0
# 3826         1.0        1.0
# 3829         1.0        1.0
# 3963         1.0        1.0
# 4040         1.0        1.0
# 4066         1.0        1.0
# 4068         1.0        1.0
# 4724         1.0        1.0
# 4883         1.0        1.0
# 5318         1.0        1.0
# 5668         1.0        1.0
# 5989         1.0        1.0
# 6162         1.0        1.0
# 6679         1.0        1.0
# 7407         1.0        1.0
# 8204         1.0        1.0
# 9090         1.0        1.0
# 9277         1.0        1.0
# 10829        1.0        1.0
# 12564        1.0        1.0
# 14577        1.0        1.0
# 18110        1.0        1.0
# 18550        1.0        1.0
# 19056        1.0        1.0
# 23114        1.0        1.0
# 23767        1.0        1.0
# 25960        1.0        1.0
# 26772        1.0        1.0
# 27798        1.0        1.0
# 27864        1.0        1.0
# 29003        1.0        1.0
# 29932        1.0        1.0
# 34698        1.0        1.0
# 49293        1.0        1.0
# 49717        1.0        1.0
# 50086        1.0        1.0
# 58856        1.0        1.0
# 59749        1.0        1.0
# 59886        1.0        1.0
# 60239        1.0        1.0
# 60989        1.0        1.0
# 61225        1.0        1.0
# 63276        1.0        1.0
# 65941        1.0        1.0
# 66055        1.0        1.0
# 73001        1.0        1.0
# 73336        1.0        1.0
# 75856        1.0        1.0
# 78233        1.0        1.0
# 81190        1.0        1.0
# 85147        1.0        1.0
# 85169        1.0        1.0

# %%
item[item.item.isin([548202, 46969, 701233, 441917, 212240, 33050, 481893, 1072221, 230026, 33081, 1020795, 59672, 225482, 438844, 641627, 382544, 514543, 884208, 65810, 639876, 196558, 735254, 154085, 289321, 230603, 176428, 414504, 313120, 753989, 354736, 543120, 313203, 543130, 543131, 543132, 547677, 543134, 123463, 138894, 204610, 365163, 71092, 204619, 451187, 543133, 995602, 210373, 11721, 97064, 479517])]
# Out:
#          item                     category  rating  review       price  \
# 9090    46969  가전·디지털|주방가전|토스터·와플메이커|일반토스터     4.8     610    178,000원
# 14577   97064        데코·식물|플라워·식물|화병·화분|화분     4.7     261         NaN
# 23114  176428             조명|무드등·장식조명|간접조명     4.8     883      8,000원
# 28303  230026                 가구|의자|인테리어의자     4.7     442     99,000원
# 60239  753989              가전·디지털|주방가전|정수기     4.9     434  1,299,000원
#
#                                         title  seller discount_rate  \
# 9090                      아이코나 전기토스터 CTOV2003    드롱기            16%
# 14577                      독일 토분 바솔트 앤티크 그래니트  밍이네가든            NaN
# 23114                LED T5 간접조명 라인조명_6colors   참라이팅            20%
# 28303           AGNS 골드벨벳체어 뿌띠 팔걸이암체어 4colors  지엠퍼니처            21%
# 60239  삼성 비스포크 직수형 냉/온 정수기 RWP71411AAP 빌트인정수기   삼성전자            22%
#
#                                                    image available_product  \
# 9090   https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 14577  https://image.ohou.se/i/bucketplace-v2-develop...               미입점
# 23114  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 28303  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 60239  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
#
#       predict_price                        preprocessed_title  \
# 9090           정보없음                         나 전기 토스터 ctov2003
# 14577          정보없음                       독일 토분 바 솔트 앤티크 그래니트
# 23114          정보없음                        led t5 간접 조명 라인 조명
# 28303          정보없음                   agns 골드 벨벳 체어 뿌띠 팔걸이 체어
# 60239          정보없음  삼성 비 스포크 직 수형 냉 온 정수기 rwp71411aap 빌트 정수기
#
#                                          similarity_list  cluster_id  \
# 9090   [['나 전기 토스터 ctov2003', '나 클래식 토스터 기 cto2003', ...        1303
# 14577                                                 []       19928
# 23114                                                 []        2490
# 28303                                                 []       30041
# 60239  [['삼성 비 스포크 직 수형 냉 온 정수기 rwp71411aap 빌트 정수기', ...        7039
#
#        mm_review  mm_rating
# 9090         1.0        1.0
# 14577        1.0        1.0
# 23114        1.0        1.0
# 28303        1.0        1.0
# 60239        1.0        1.0

# %%
item[item.item.isin([204615, 745550, 550989, 481893, 246017, 176428, 97064, 582913, 237059, 225484, 313120, 747576, 753989, 544635, 204610])]
# Out:
#          item                   category  rating  review       price  \
# 14577   97064      데코·식물|플라워·식물|화병·화분|화분     4.7     261         NaN
# 23114  176428           조명|무드등·장식조명|간접조명     4.8     883      8,000원
# 27798  225484        데코·식물|인테리어소품|모빌·가랜드     4.7     395     82,500원
# 29932  246017          가구|진열장·책장|진열장·장식장     4.5     521         NaN
# 49717  544635        조명|무드등·장식조명|무드등·수유등     4.9     229         NaN
# 50086  550989  가전·디지털|주방가전|커피메이커·머신|커피머신     4.9     531    299,000원
# 59749  745550    가전·디지털|주방가전|오븐·전자레인지|오븐     4.8     280    999,000원
# 59886  747576          가전·디지털|냉장고|양문형냉장고     4.9     647  2,890,000원
# 60239  753989            가전·디지털|주방가전|정수기     4.9     434  1,299,000원
#
#                                               title  seller discount_rate  \
# 14577                            독일 토분 바솔트 앤티크 그래니트  밍이네가든            NaN
# 23114                      LED T5 간접조명 라인조명_6colors   참라이팅            20%
# 27798            FLENSTED MOBILES 모빌 - 미래 블랙 FUTURA  플렌스테드            17%
# 29932                                 브릭나인 인테리어 벽난로   브릭나인            NaN
# 49717                  미나 LED 미니 버섯램프_LH60 12colors     렉슨            NaN
# 50086  [공식인증] 네스프레소 버츄오플러스 블랙/화이트/실버/매트블랙 + 캡슐12개포함  네스프레소            33%
# 59749                LG 디오스 광파오븐 오브제컬렉션 ML32EW1 32L   LG전자            36%
# 59886               비스포크 키친핏 4도어 냉장고 RF60B91C3AP 코타   삼성전자            26%
# 60239        삼성 비스포크 직수형 냉/온 정수기 RWP71411AAP 빌트인정수기   삼성전자            22%
#
#                                                    image available_product  \
# 14577  https://image.ohou.se/i/bucketplace-v2-develop...               미입점
# 23114  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 27798  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 29932  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 49717  https://image.ohou.se/i/bucketplace-v2-develop...               미입점
# 50086  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 59749  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 59886  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 60239  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
#
#       predict_price                        preprocessed_title  \
# 14577          정보없음                       독일 토분 바 솔트 앤티크 그래니트
# 23114          정보없음                        led t5 간접 조명 라인 조명
# 27798          정보없음          flensted mobiles 모빌 미래 블랙 futura
# 29932          정보없음                            브릭 나인 인테리어 벽난로
# 49717        39,900                           미나 led 미니 버섯 램프
# 50086          정보없음      네스프레소 버츄 플러스 블랙 화이트 실버 매트 블랙 캡슐 개 포함
# 59749          정보없음               lg 디오스 광파 오븐 오브 컬렉션 ml32ew1
# 59886          정보없음          비 스포크 키친 핏 도어 냉장고 rf60b91c3ap 코타
# 60239          정보없음  삼성 비 스포크 직 수형 냉 온 정수기 rwp71411aap 빌트 정수기
#
#                                          similarity_list  cluster_id  \
# 14577                                                 []       19928
# 23114                                                 []        2490
# 27798  [['flensted mobiles 모빌 미래 블랙 futura', 'flenste...        3595
# 29932                                                 []       31262
# 49717                                                 []       44337
# 50086                                                 []       44545
# 59749  [['lg 디오스 광파 오븐 오브 컬렉션 ml32ew1', 'lg 디오스 광파 오븐...        6999
# 59886  [['비 스포크 키친 핏 도어 냉장고 rf60b91c3ap 코타', '비 스포크 키...        4263
# 60239  [['삼성 비 스포크 직 수형 냉 온 정수기 rwp71411aap 빌트 정수기', ...        7039
#
#        mm_review  mm_rating
# 14577        1.0        1.0
# 23114        1.0        1.0
# 27798        1.0        1.0
# 29932        1.0        1.0
# 49717        1.0        1.0
# 50086        1.0        1.0
# 59749        1.0        1.0
# 59886        1.0        1.0
# 60239        1.0        1.0

# %%
# import webbrowser
# import time

# # t = [204615, 745550, 550989, 481893, 246017, 176428, 97064, 582913, 237059, 225484, 313120, 747576, 753989, 544635, 204610]
# t = [33050, 441917, 212240, 876149, 30484, 41712, 853362, 30495, 33081, 30504, 33086, 1152, 38925, 33089, 30528, 639470, 38945, 30532, 38947, 38951, 563197, 38953, 26926, 38963, 909706, 909717, 315076, 544635, 1320247, 36594, 48152, 768611, 386975, 176428, 14395, 61315, 1092386, 225061, 387093, 387106, 33580, 748742, 123463, 310209, 1321586, 33735, 280948, 135891, 1055509, 303875, 18446, 131781, 1325, 1036195, 131838, 31085, 33852, 68422, 680807, 481893, 537573, 225482, 213839, 225484, 310706, 172680, 42545, 136673, 1450530, 641627, 181848, 88674, 34103, 414026, 1451760, 31336, 128435, 691069, 735254, 414449, 24302, 109802, 348334, 1026007, 1399771, 69056, 1154849, 148603, 2699, 354736, 182232, 226085, 567071, 89085, 34624, 547677, 624613, 155409, 451187, 1071454, 246017, 11721, 11727, 97064, 11729, 451232, 37307, 11733, 306151, 11738, 11731, 429064, 11750, 823099, 173544, 363774, 701233, 1072212, 1072221, 752541, 2864, 1006410, 19486, 79841, 1006485, 438844, 237045, 149087, 1171337, 237059, 1157216, 1060151, 485244, 1248819, 19562, 1028902, 773248, 1060535, 938129, 65810, 814245, 31965, 251331, 981458, 1084568, 58467, 312920, 15735, 872870, 702583, 15833, 169066, 605321, 49639, 12589, 1158159, 585078, 237554, 313120, 753989, 682, 32125, 313203, 169244, 153526, 705, 16201, 540903, 745550, 138894, 204610, 71092, 29275, 204619, 995584, 995602, 995590, 204611, 313488, 336837, 204615, 32199, 13082, 158184, 46969, 826577, 1235652, 328613, 307885, 1020795, 252272, 874418, 264565, 1160354, 170039, 36011, 550989, 675895, 884208, 83763, 130321, 308338, 117522, 38483, 13236, 954778, 1076749, 153835, 766950, 224146, 1414013, 13495, 13505, 13524, 731281, 747576, 17023, 38044, 30335, 1276387, 1276391]

# for a in (item[(item.item.isin(t)) & (item.review > 0)].image):
#     webbrowser.open(a)
# # item[(item.item.isin(t)) & (item.review > 0)]

# %%
item[(item.item.isin(t)) & (item.review > 0)]
# Out:
#           item                      category  rating  review       price  \
# 3824     11727                 가구|서랍·수납장|수납장     4.6     389         NaN
# 3826     11729                   가구|의자|스툴·벤치     4.7     610         NaN
# 3829     11733                   가구|의자|스툴·벤치     4.6     749      9,000원
# 3963     13082              데코·식물|시계|알람·탁상시계     4.8     233         NaN
# 4040     13236                  패브릭|쿠션·방석|쿠션     4.7     545         NaN
# 4066     13505                  가구|의자|인테리어의자     4.7     616     22,900원
# 4068     13524              패브릭|주방패브릭|행주·티타월     4.7     863         NaN
# 4724     18446          데코·식물|플라워·식물|식물|다육식물     4.7     486         NaN
# 4883     19486     데코·식물|디퓨저·캔들|캔들홀더·워머|캔들홀더     4.7     371         NaN
# 5318     24302         데코·식물|플라워·식물|화병·화분|화분     4.6     641         NaN
# 5668     26926       주방용품|보관·용기·도시락|밀폐용기·반찬통     4.5     681     55,200원
# 5989     29275           가구|테이블·식탁·책상|사이드테이블     4.7     525     17,600원
# 6162     30504                  가구|의자|인테리어의자     4.6     301     61,000원
# 6679     33089           가구|테이블·식탁·책상|사이드테이블     4.7     634         NaN
# 7407     37307           가구|테이블·식탁·책상|사이드테이블     4.7     999     47,900원
# 8204     41712                   가구|의자|스툴·벤치     4.5     356     97,000원
# 9090     46969   가전·디지털|주방가전|토스터·와플메이커|일반토스터     4.8     610    178,000원
# 9277     48152                 가구|서랍·수납장|수납장     4.7     371         NaN
# 10829    61315          가구|테이블·식탁·책상|책상|일반책상     4.5     351         NaN
# 12564    79841  가전·디지털|음향가전|스피커|블루투스·인공지능스피커     4.8     690         NaN
# 14577    97064         데코·식물|플라워·식물|화병·화분|화분     4.7     261         NaN
# 18110   128435                  가구|서랍·수납장|협탁     4.6     328    169,000원
# 18550   131781                       조명|장스탠드     4.9     464         NaN
# 19056   135891      가구|테이블·식탁·책상|식탁|식탁·입식테이블     4.5     656    535,000원
# 23114   176428              조명|무드등·장식조명|간접조명     4.8     883      8,000원
# 23767   182232                 가구|서랍·수납장|수납장     4.8     266         NaN
# 25960   204611             가전·디지털|계절가전|공기청정기     4.8     274    749,000원
# 26772   213839             가전·디지털|계절가전|공기청정기     4.6     477    299,000원
# 27798   225484           데코·식물|인테리어소품|모빌·가랜드     4.7     395     82,500원
# 27864   226085               가구|선반|벽선반|무지주선반     4.7     278         NaN
# 29003   237554  주방용품|보관·용기·도시락|쌀통·브레드박스·디스펜서     4.7     244     24,900원
# 29932   246017             가구|진열장·책장|진열장·장식장     4.5     521         NaN
# 34698   307885              조명|무드등·장식조명|간접조명     4.8     378      6,000원
# 49293   537573                   가구|의자|스툴·벤치     4.7     500         NaN
# 49717   544635           조명|무드등·장식조명|무드등·수유등     4.9     229         NaN
# 50086   550989     가전·디지털|주방가전|커피메이커·머신|커피머신     4.9     531    299,000원
# 58856   731281        가전·디지털|TV|189cm~(75"~)     4.8     401  3,392,000원
# 59749   745550       가전·디지털|주방가전|오븐·전자레인지|오븐     4.8     280    999,000원
# 59886   747576             가전·디지털|냉장고|양문형냉장고     4.9     647  2,890,000원
# 60239   753989               가전·디지털|주방가전|정수기     4.9     434  1,299,000원
# 60989   768611   가전·디지털|TV|164~188cm(65~74")     4.9     556  1,700,000원
# 61225   773248               가구|선반|벽선반|무지주선반     4.6     269     19,500원
# 63276   814245                       조명|단스탠드     4.8     493    270,000원
# 65941   874418     데코·식물|디퓨저·캔들|캔들홀더·워머|캔들홀더     4.8     366     61,000원
# 66055   876149   가전·디지털|주방가전|식기세척기·건조기|식기세척기     4.9     278  1,490,000원
# 73001  1028902                       조명|단스탠드     4.7     332    220,000원
# 73336  1036195             가전·디지털|냉장고|양문형냉장고     4.9     336         NaN
# 75856  1092386       가전·디지털|주방가전|오븐·전자레인지|오븐     4.9     273    690,000원
# 78233  1160354   가전·디지털|주방가전|식기세척기·건조기|식기세척기     4.9     220  1,490,000원
# 81190  1248819     가전·디지털|주방가전|가스레인지·인덕션|인덕션     4.9     303  1,390,000원
# 85147  1450530             가전·디지털|냉장고|양문형냉장고     4.9     276  2,800,000원
# 85169  1451760     가전·디지털|주방가전|가스레인지·인덕션|인덕션     4.9     425  1,590,000원
#
#                                                    title   seller  \
# 3824                                         PS 캐비넷 수납장      이케아
# 3826                                   FROSTA 스툴 3colors     이케아
# 3829                                       MARIUS 디자인 스툴     이케아
# 3963            친환경 LED 나무알람시계 4종 Real Wooden Clock 리얼우드     무아스
# 4040                          테마 레터링 쿠션/방석(단품&세트) 14종 택1     아이르
# 4066                                     ADDE 체어 4colors     이케아
# 4068                                             ELLY 행주     이케아
# 4724                              공기정화 / 전자파차단 미니 스투키 4종    피플랜트
# 4883                           ROTERA 미니 양초 랜턴 4colors       이케아
# 5318                         내츄럴 해초바구니(왕골 항아리바구니) 12type     꾸미까
# 5668                                    NEW 시리얼 디스펜서 17종     제브로
# 5989                                      GLADOM 트레이 테이블     이케아
# 6162                                       헤이 체어 7colors   체어팩토리
# 6679                                   NETUD 원목 수납테이블 2종     마켓비
# 7407                                         메이저 사이드 테이블    소프시스
# 8204                               모니카 니트스툴/푸프스툴 6colors    아카시아
# 9090                                 아이코나 전기토스터 CTOV2003     드롱기
# 9277                                  FILMON 시리즈 3colors     마켓비
# 10829                         베이직 책상 40 입식/좌식 22type\t\t    블루밍홈
# 12564                        공식국내배송 액톤2 블루투스 스피커 2colors      마샬
# 14577                                 독일 토분 바솔트 앤티크 그래니트   밍이네가든
# 18110                           킨포/알렉스 2단 550 협탁 5colors   아이엔지홈
# 18550                    (안전포장) LERSTA 레르스타 장스탠드_3colors     이케아
# 19056                               [할인쿠폰] 피카 확장형 4인 테이블    오투가구
# 23114                           LED T5 간접조명 라인조명_6colors    참라이팅
# 23767                        알렉스 1200 높은 수납장 ALEX 3color   아이엔지홈
# 25960                        더 퓨어 공기청정기 2colors 60㎡ 18평형     발뮤다
# 26772                                   [해외] 미에어2S 공기청정기     샤오미
# 27798                 FLENSTED MOBILES 모빌 - 미래 블랙 FUTURA   플렌스테드
# 27864                                     MOSSLANDA 액자선반     이케아
# 29003                                    틴 라이스박스/쌀통+계량컵      키펙스
# 29932                                      브릭나인 인테리어 벽난로    브릭나인
# 34698                     LED T5 형광등 SSEN_4sizes/3colors   공간LED
# 49293                                     BEKVAM 베크벰스텝스툴     이케아
# 49717                       미나 LED 미니 버섯램프_LH60 12colors      렉슨
# 50086       [공식인증] 네스프레소 버츄오플러스 블랙/화이트/실버/매트블랙 + 캡슐12개포함   네스프레소
# 58856        삼세페 삼성공식인증몰 QLED 4K  TV KQ75QA65AFXKR 189cm    삼성전자
# 59749                     LG 디오스 광파오븐 오브제컬렉션 ML32EW1 32L    LG전자
# 59886                    비스포크 키친핏 4도어 냉장고 RF60B91C3AP 코타    삼성전자
# 60239             삼성 비스포크 직수형 냉/온 정수기 RWP71411AAP 빌트인정수기    삼성전자
# 60989  [연휴특가/102만] 삼성 공식 UHD TV  KU65UA8070FXKR 163cm...    삼성전자
# 61225                             인테리어 무지주 벽선반 30T 4size  우드리퍼블릭
# 63276               신상 레드 컬러 입고! [해외] 네시노 테이블 램프 3colors   아르테미데
# 65941                               빈티지 무드의 나무 소품, 벽거울촛대  클라우드살몬
# 66055               비스포크 12인용 열풍건조 식기세척기 DW60A8355FG 인증점    삼성전자
# 73001                          [해외]네시노 테이블 램프 오렌지/화이트/레드   아르테미데
# 73336              LG 디오스 오브제컬렉션 냉장고 M872AAA031 870L 조합형    LG전자
# 75856                 비스포크 큐커 전기오븐 MO22A7797CWR 22리터 인증점    삼성전자
# 78233           [오늘의딜] LG 디오스 식기세척기 오브제컬렉션 DUBJ2EAL 12인용    LG전자
# 81190    [혜택가87만원대]비스포크 인덕션 NZ63B8708XH 3구 전기레인지 빌트인 화이트    삼성전자
# 85147                  LG 디오스 노크온 오브제컬렉션 T873MEE312 870L    LG전자
# 85169  [오늘의딜/카드혜택 72만원대]삼성전자 비스포크 3구 인덕션 화이트 NZ63B650...    삼성전자
#
#       discount_rate                                              image  \
# 3824            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 3826            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 3829             1%  https://image.ohou.se/i/bucketplace-v2-develop...
# 3963            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 4040            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 4066            19%  https://image.ohou.se/i/bucketplace-v2-develop...
# 4068            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 4724            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 4883            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 5318            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 5668            50%  https://image.ohou.se/i/bucketplace-v2-develop...
# 5989             4%  https://image.ohou.se/i/bucketplace-v2-develop...
# 6162            35%  https://image.ohou.se/i/bucketplace-v2-develop...
# 6679            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 7407            37%  https://image.ohou.se/i/bucketplace-v2-develop...
# 8204            59%  https://image.ohou.se/i/bucketplace-v2-develop...
# 9090            16%  https://image.ohou.se/i/bucketplace-v2-develop...
# 9277            NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 10829           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 12564           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 14577           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 18110           55%  https://image.ohou.se/i/bucketplace-v2-develop...
# 18550           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 19056           22%  https://image.ohou.se/i/bucketplace-v2-develop...
# 23114           20%  https://image.ohou.se/i/bucketplace-v2-develop...
# 23767           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 25960           20%  https://image.ohou.se/i/bucketplace-v2-develop...
# 26772           41%  https://image.ohou.se/i/bucketplace-v2-develop...
# 27798           17%  https://image.ohou.se/i/bucketplace-v2-develop...
# 27864           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 29003           20%  https://image.ohou.se/i/bucketplace-v2-develop...
# 29932           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 34698           35%  https://image.ohou.se/i/bucketplace-v2-develop...
# 49293           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 49717           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 50086           33%  https://image.ohou.se/i/bucketplace-v2-develop...
# 58856           46%  https://image.ohou.se/i/bucketplace-v2-develop...
# 59749           36%  https://image.ohou.se/i/bucketplace-v2-develop...
# 59886           26%  https://image.ohou.se/i/bucketplace-v2-develop...
# 60239           22%  https://image.ohou.se/i/bucketplace-v2-develop...
# 60989           36%  https://image.ohou.se/i/bucketplace-v2-develop...
# 61225           25%  https://image.ohou.se/i/bucketplace-v2-develop...
# 63276           35%  https://image.ohou.se/i/bucketplace-v2-develop...
# 65941            2%  https://image.ohou.se/i/bucketplace-v2-develop...
# 66055           26%  https://image.ohou.se/i/bucketplace-v2-develop...
# 73001           22%  https://image.ohou.se/i/bucketplace-v2-develop...
# 73336           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
# 75856           34%  https://image.ohou.se/i/bucketplace-v2-develop...
# 78233           33%  https://image.ohou.se/i/bucketplace-v2-develop...
# 81190           33%  https://image.ohou.se/i/bucketplace-v2-develop...
# 85147           32%  https://image.ohou.se/i/bucketplace-v2-develop...
# 85169           52%  https://image.ohou.se/i/bucketplace-v2-develop...
#
#       available_product predict_price  \
# 3824                NaN          정보없음
# 3826                미입점        14,100
# 3829                NaN          정보없음
# 3963                미입점          정보없음
# 4040                미입점          정보없음
# 4066                NaN          정보없음
# 4068                NaN          정보없음
# 4724                미입점          정보없음
# 4883                NaN          정보없음
# 5318                미입점          정보없음
# 5668                NaN          정보없음
# 5989                NaN          정보없음
# 6162                NaN          정보없음
# 6679                미입점          정보없음
# 7407                NaN          정보없음
# 8204                NaN          정보없음
# 9090                NaN          정보없음
# 9277                미입점          정보없음
# 10829               미입점          정보없음
# 12564               NaN          정보없음
# 14577               미입점          정보없음
# 18110               NaN          정보없음
# 18550               미입점        19,900
# 19056               NaN          정보없음
# 23114               NaN          정보없음
# 23767               미입점       124,000
# 25960               NaN          정보없음
# 26772               NaN          정보없음
# 27798               NaN          정보없음
# 27864               NaN          정보없음
# 29003               NaN          정보없음
# 29932               NaN          정보없음
# 34698               NaN          정보없음
# 49293               NaN          정보없음
# 49717               미입점        39,900
# 50086               NaN          정보없음
# 58856               NaN          정보없음
# 59749               NaN          정보없음
# 59886               NaN          정보없음
# 60239               NaN          정보없음
# 60989               NaN          정보없음
# 61225               NaN          정보없음
# 63276               NaN          정보없음
# 65941               NaN          정보없음
# 66055               NaN          정보없음
# 73001               NaN          정보없음
# 73336               NaN          정보없음
# 75856               NaN          정보없음
# 78233               NaN          정보없음
# 81190               NaN          정보없음
# 85147               NaN          정보없음
# 85169               NaN          정보없음
#
#                               preprocessed_title  \
# 3824                                   ps 캐비넷 수납
# 3826                                   frosta 스툴
# 3829                               marius 디자인 스툴
# 3963   친환경 led 나무 알람시계 종 real wooden clock 리얼 우드
# 4040                      테마 레터 링 쿠션 방석 품 세트 종 택
# 4066                                     adde 체어
# 4068                                     elly 행주
# 4724                       공기 정화 전자파 차단 미니 스투키 종
# 4883                             rotera 미니 양초 랜턴
# 5318                       내츄럴 해초 바구니 왕골 항아리 바구니
# 5668                             new 시리얼 디 스펜서 종
# 5989                             gladom 트 레이 테이블
# 6162                                       헤이 체어
# 6679                           netud 원목 수납 테이블 종
# 7407                                 메이저 사이드 테이블
# 8204                              모니카 니트 스툴 푸프스툴
# 9090                           나 전기 토스터 ctov2003
# 9277                                  filmon 시리즈
# 10829                              베이직 책상 40 입 좌
# 12564                       공식 국내 배송 액톤 블루투스 스피커
# 14577                        독일 토분 바 솔트 앤티크 그래니트
# 18110                            킨포 알렉스 단 550 협탁
# 18550                         lersta 레르 스타 장 스탠드
# 19056                                피카 확장 인 테이블
# 23114                         led t5 간접 조명 라인 조명
# 23767                           알렉스 1200 수납 alex
# 25960                           더 퓨어 공기청정기 60 평형
# 26772                                   에어 공기청정기
# 27798           flensted mobiles 모빌 미래 블랙 futura
# 27864                            mosslanda 액자 선반
# 29003                            틴 라이스 박스 쌀통 계량컵
# 29932                             브릭 나인 인테리어 벽난로
# 34698                     led t5 형광등 ssen 4sizes
# 49293                            bekvam 베크 스텝스 툴
# 49717                            미나 led 미니 버섯 램프
# 50086       네스프레소 버츄 플러스 블랙 화이트 실버 매트 블랙 캡슐 개 포함
# 58856              페 공식 인증 qled tv kq75qa65afxkr
# 59749                lg 디오스 광파 오븐 오브 컬렉션 ml32ew1
# 59886           비 스포크 키친 핏 도어 냉장고 rf60b91c3ap 코타
# 60239   삼성 비 스포크 직 수형 냉 온 정수기 rwp71411aap 빌트 정수기
# 60989             삼성 공식 uhd tv ku65ua8070fxkr 65
# 61225                             인테리어 무 지주 벽 선반
# 63276                       신상 레드 컬러 해외 노 테이블 램프
# 65941                        빈티 무드 나무 소품 벽 거울 촛대
# 66055      비 스포크 인용 열풍 건조 식기세척기 dw60a8355fg 인증 점
# 73001                        노 테이블 램프 오렌지 화이트 레드
# 73336           lg 디오스 오브 컬렉션 냉장고 m872aaa031 조합형
# 75856         비 스포크 큐 전기 오븐 mo22a7797cwr 리터 인증 점
# 78233            lg 디오스 식기세척기 오브 컬렉션 dubj2eal 인용
# 81190       비 스포크 인덕션 nz63b8708xh 구 전기레인지 빌트 화이트
# 85147              lg 디오스 노크 온 오브 컬렉션 t873mee312
# 85169          삼성 전자 비 스포크 구 인덕션 화이트 nz63b6502xh
#
#                                          similarity_list  cluster_id  \
# 3824                                                  []         539
# 3826                                                  []       11856
# 3829   [['marius 디자인 스툴', 'marius 스툴', 149202, 0.8181...         541
# 3963                                                  []       11945
# 4040                                                  []       11992
# 4066                                                  []       12007
# 4068         [['elly 행주', 'elly 행주 가지 색상', 190204, 0.7]]       12008
# 4724                                                  []       12488
# 4883                                                  []         726
# 5318                                                  []       12934
# 5668   [['new 시리얼 디 스펜서 종', 'new 헤일리 시리얼 디 스펜서', 2811...         829
# 5989   [['gladom 트 레이 테이블', 'gladom 트 레이 테이블', 157523...         877
# 6162   [['헤이 체어', '헤이베 체어 색', 1229926, 0.769230769230...       13518
# 6679                                                  []       13903
# 7407                                                  []        1095
# 8204                                                  []       15048
# 9090   [['나 전기 토스터 ctov2003', '나 클래식 토스터 기 cto2003', ...        1303
# 9277                                                  []       15882
# 10829                                                 []        1545
# 12564                                                 []       18363
# 14577                                                 []       19928
# 18110                                                 []       22625
# 18550  [['lersta 레르 스타 장 스탠드', 'lersta 레르 스타 플로 스탠드',...        2508
# 19056  [['피카 확장 인 테이블', '피카 확장 테이블', 25185, 0.9], ['피...         795
# 23114                                                 []        2490
# 23767  [['알렉스 1200 수납 alex', '알렉스 1200 수납 alex 화이트', ...        3178
# 25960                                                 []       28271
# 26772  [['에어 공기청정기', '에어 공기청정기 한글 판', 215478, 0.76190...        1449
# 27798  [['flensted mobiles 모빌 미래 블랙 futura', 'flenste...        3595
# 27864                                                 []        2818
# 29003                                                 []       30570
# 29932                                                 []       31262
# 34698                                                 []       34646
# 49293  [['bekvam 베크 스텝스 툴', 'bekvam 베크 원목 스텝스 툴 계단 스툴...        2043
# 49717                                                 []       44337
# 50086                                                 []       44545
# 58856  [['페 공식 인증 qled tv kq75qa65afxkr', '페 공식 인증 삼성...        6905
# 59749  [['lg 디오스 광파 오븐 오브 컬렉션 ml32ew1', 'lg 디오스 광파 오븐...        6999
# 59886  [['비 스포크 키친 핏 도어 냉장고 rf60b91c3ap 코타', '비 스포크 키...        4263
# 60239  [['삼성 비 스포크 직 수형 냉 온 정수기 rwp71411aap 빌트 정수기', ...        7039
# 60989                                                 []       51946
# 61225  [['인테리어 무 지주 벽 선반', '인테리어 무 지주 선반 거실 벽 선반 종 택'...         612
# 63276                                                 []       53499
# 65941                                                 []       55373
# 66055                                                 []       55459
# 73001  [['노 테이블 램프 오렌지 화이트 레드', '노 테이블 램프 조명 화이트', 79...       60441
# 73336  [['lg 디오스 오브 컬렉션 냉장고 m872aaa031 조합형', 'lg 디오스 ...        8010
# 75856                                                 []        8194
# 78233  [['lg 디오스 식기세척기 오브 컬렉션 dubj2eal 인용', 'lg 디오스 식...        6757
# 81190  [['비 스포크 인덕션 nz63b8708xh 구 전기레인지 빌트 화이트', '비 스...       66431
# 85147  [['lg 디오스 노크 온 오브 컬렉션 t873mee312', 'lg 디오스 베이직...        8629
# 85169                                                 []       69337
#
#        mm_review  mm_rating
# 3824         1.0        1.0
# 3826         1.0        1.0
# 3829         1.0        1.0
# 3963         1.0        1.0
# 4040         1.0        1.0
# 4066         1.0        1.0
# 4068         1.0        1.0
# 4724         1.0        1.0
# 4883         1.0        1.0
# 5318         1.0        1.0
# 5668         1.0        1.0
# 5989         1.0        1.0
# 6162         1.0        1.0
# 6679         1.0        1.0
# 7407         1.0        1.0
# 8204         1.0        1.0
# 9090         1.0        1.0
# 9277         1.0        1.0
# 10829        1.0        1.0
# 12564        1.0        1.0
# 14577        1.0        1.0
# 18110        1.0        1.0
# 18550        1.0        1.0
# 19056        1.0        1.0
# 23114        1.0        1.0
# 23767        1.0        1.0
# 25960        1.0        1.0
# 26772        1.0        1.0
# 27798        1.0        1.0
# 27864        1.0        1.0
# 29003        1.0        1.0
# 29932        1.0        1.0
# 34698        1.0        1.0
# 49293        1.0        1.0
# 49717        1.0        1.0
# 50086        1.0        1.0
# 58856        1.0        1.0
# 59749        1.0        1.0
# 59886        1.0        1.0
# 60239        1.0        1.0
# 60989        1.0        1.0
# 61225        1.0        1.0
# 63276        1.0        1.0
# 65941        1.0        1.0
# 66055        1.0        1.0
# 73001        1.0        1.0
# 73336        1.0        1.0
# 75856        1.0        1.0
# 78233        1.0        1.0
# 81190        1.0        1.0
# 85147        1.0        1.0
# 85169        1.0        1.0

# %%
import os

data_path = "../backend/data/"

train = (
    pd.read_csv(os.path.join(data_path, "train.tsv"), sep="\t")
    .groupby("house")
    .filter(lambda x: len(x) >= 15)
)
item = (
    pd.read_csv(os.path.join(data_path, "item.tsv"), sep="\t")
)
a = item[item.rating == 'ņĀÉ 5.0ņĀ']
b = item[item.rating == 'м†Р 4.8м†']
tmp = list(a.index)
tmp.extend(list(b.index))

tmp2 = list(train[train.item == a.item.values[0]].index)
tmp2.extend(list(train[train.item == b.item.values[0]].index))

item.drop(index=tmp, inplace=True)
train.drop(index=tmp2, inplace=True)
# Out:
# /tmp/ipykernel_672/3693566341.py:11: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(os.path.join(data_path, "item.tsv"), sep="\t")

# %%
train.item.nunique()
# Out:
# 82026

# %%
import os

data_path = "../backend/data/"

train = (
    pd.read_csv(os.path.join(data_path, "train.tsv"), sep="\t")
)
item = (
    pd.read_csv(os.path.join(data_path, "item.tsv"), sep="\t")
)
a = item[item.rating == 'ņĀÉ 5.0ņĀ']
b = item[item.rating == 'м†Р 4.8м†']
tmp = list(a.index)
tmp.extend(list(b.index))

tmp2 = list(train[train.item == a.item.values[0]].index)
tmp2.extend(list(train[train.item == b.item.values[0]].index))

item.drop(index=tmp, inplace=True)
train.drop(index=tmp2, inplace=True)

train = train.groupby("house").filter(lambda x: len(x) >= 15)
# Out:
# /tmp/ipykernel_672/3558813943.py:9: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(os.path.join(data_path, "item.tsv"), sep="\t")

# %%
train.item.nunique()
# Out:
# 82026

# %%
train = (
    pd.read_csv(os.path.join(data_path, "train.tsv"), sep="\t")
)

train.item.nunique()
# Out:
# 88935

# %%
train.to_csv("../backend/data/train_.tsv", sep="\t", index=False)

# %%
train = (
    pd.read_csv(os.path.join(data_path, "train.tsv"), sep="\t")
)

train = train.groupby("house").filter(lambda x: len(x) >= 15)

train.item.nunique()
# Out:
# 82028

# %%
train.to_csv("../backend/data/train_.tsv", sep="\t", index=False)

# %%
item.sort_values("title", inplace=True)

# %%
print(item[10003:100010].title)
# Out:
# 10227                           INDIRA 인디라 베드스프레드
# 43031           INDIRA 인디라 베드스프레드, 화이트 230x250 cm
# 13140                          INDUSTRIELL 인두스트리엘
# 12863                      INDUSTRIELL 인두스트리엘 암체어
# 33590    INDUSTRIELL 인두스트리엘 의자, 그린블랙 (903.945.21)
#                            ...
# 67986                              ﻿화이트 설유화 가지 조화
# 66897                    ﻿화이트 앤틱로즈 찔레장미 조화 꽃다발 세트
# 82521                          ﻿화이트라인 클레마티스 조화 화분
# 22442                 ［재입고］우드 핸들 화이트 식기정리대 1단 물빠짐
# 50816                                🌿라탄 자개 드림캐쳐🌿
# Name: title, Length: 78930, dtype: object

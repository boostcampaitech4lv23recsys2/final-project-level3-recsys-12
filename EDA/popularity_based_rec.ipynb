# %%
import pandas as pd

# %%
item = pd.read_csv("../crawling/output/item.tsv", sep="\t")
# Out:
# /tmp/ipykernel_6261/991992001.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   item = pd.read_csv("../crawling/output/item.tsv", sep="\t")

# %%
item.head(1)
# Out:
#    item       category rating  review price preprocessed_title   seller  \
# 0     1  가구|서랍·수납장|수납장    4.2      67   NaN              66808  DRAWER
#
#   discount_rate                                              image  \
# 0           NaN  https://image.ohou.se/i/bucketplace-v2-develop...
#
#   available_product predict_price original_title similarity_list  cluster_id  \
# 0               미입점          정보없음          66808              []        8843
#
#    rating_  review_
# 0      NaN        0

# %%
item.rating.fillna("0.0", inplace=True)

# %%
item[item.rating == ("ņĀÉ 5.0ņĀ")]
# Out:
#          item                    category     rating  review       price  \
# 44731  459007  Ļ░ĆĻĄ¼|ņåīĒīī|ņØ╝ļ░śņåīĒīī  ņĀÉ 5.0ņĀ       1  450,000ņøÉ
#
#       preprocessed_title            seller discount_rate  \
# 44731                NaN  ļØ╝ņØ┤ĒĢÅĻ░ĆĻĄ¼            28%
#
#                                                    image available_product  \
# 44731  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
#
#       predict_price                                     original_title  \
# 44731          정보없음  ļģĖļō£ļ”Ł Ēī©ļĖīļ”Ł ļ¬©ļŹś ļ»ĖļŗłņåīĒīī ļ▓Āļō£...
#
#                                          similarity_list  cluster_id  rating_  \
# 44731  [['', '', 494730, 1.0], ['', '', 44104, 1.0], ...         129      NaN
#
#        review_
# 44731        0

# %%
item[item.rating == ('м†Р 4.8м†')].index
# Out:
# Int64Index([61900], dtype='int64')

# %%
item.drop(item[item.rating == ("м†Р 4.8м†")].index, inplace=True)
item.drop(item[item.rating == ("ņĀÉ 5.0ņĀ")].index, inplace=True)

# %%
item.rating = item.rating.astype(float)
item.review = item.review.astype(int)

# %%
import numpy as np

bins = list(np.arange(0, 5.5, 0.5))
item["rating_binned"] = pd.cut(item["rating"], bins)

# %%
item.rating_binned.value_counts()[:]
# Out:
# (4.5, 5.0]    44163
# (4.0, 4.5]     8009
# (3.5, 4.0]     2680
# (2.5, 3.0]      468
# (3.0, 3.5]      216
# (1.5, 2.0]       71
# (0.5, 1.0]       31
# (2.0, 2.5]        9
# (0.0, 0.5]        0
# (1.0, 1.5]        0
# Name: rating_binned, dtype: int64

# %%
item.rating_binned.value_counts()[:1].sum()
# Out:
# 44163

# %%
item.rating_binned.value_counts()[1:].sum()
# Out:
# 11484

# %%
import numpy as np

bins = list(np.arange(0, 5.5, 1))
item["rating_binned"] = pd.cut(item["rating"], bins)

# %%
item.rating_binned.value_counts()[:]
# Out:
# (4.0, 5.0]    52172
# (3.0, 4.0]     2896
# (2.0, 3.0]      477
# (1.0, 2.0]       71
# (0.0, 1.0]       31
# Name: rating_binned, dtype: int64

# %%
NEGATIVE_RATING = 4.0

# %%
item = item[~(item.rating == 0)]

# %%
item[(item.rating <= NEGATIVE_RATING)]
# Out:
#           item                    category  rating  review    price  \
# 43         106      주방용품|보관·용기·도시락|양념통·오일병     4.0       1      NaN
# 73         170         주방용품|주방수납·정리|주방수납용품     3.5       2      NaN
# 84         182                가구|서랍·수납장|협탁     4.0       1      NaN
# 89         192             패브릭|매트|주방·다용도매트     4.0       1      NaN
# 94         204                     조명|장스탠드     4.0       2      NaN
# ...        ...                         ...     ...     ...      ...
# 88402  1727911  가전·디지털|휴대폰|휴대폰액세서리|그립톡·거치대     3.0       1      NaN
# 88459  1737485         조명|무드등·장식조명|무드등·수유등     4.0       1  68,800원
# 88542  1747887              가구|선반|벽선반|지주선반     4.0       1  46,000원
# 88599  1755228                패브릭|홈패브릭|실내화     4.0       2  45,000원
# 88643  1766679       데코·식물|디퓨저·캔들|아로마오일·워머     4.0       2  69,000원
#
#                        preprocessed_title   seller discount_rate  \
# 43                          h 스마트 프레 쉬 일병   모던하우스            NaN
# 73                vurm 4 bottle wine rack     이케아            NaN
# 84                               그린티 등 탁자     리바트            NaN
# 89                        블루 피쉬 극세사 키친 매트    쁘리엘르            NaN
# 94                           스프링 플로 장 스탠드  LAMPDA            NaN
# ...                                   ...      ...           ...
# 88402         h 에어팟 맥스 헤드폰 거치 알루미늄 스탠드 색상     엘라고            NaN
# 88459      크리스마스 산타 캔디 하우스 골 워터볼 스노우볼 무드등   본디자인랩            20%
# 88542   우드 현관 마그넷 자석 마스크 걸이 구 number 후크 개  모이 Moy            28%
# 88599  hodgehog toweling slides 타월 링 슬라이드   씨피티에스            10%
# 88643              천연 아로마 에센셜 블렌딩 오일 종 세트     핀블랑             7%
#
#                                                    image available_product  \
# 43     https://image.ohou.se/i/bucketplace-v2-develop...               미입점
# 73     https://image.ohou.se/i/bucketplace-v2-develop...               미입점
# 84     https://image.ohou.se/i/bucketplace-v2-develop...               미입점
# 89     https://image.ohou.se/i/bucketplace-v2-develop...               미입점
# 94     https://image.ohou.se/i/bucketplace-v2-develop...               미입점
# ...                                                  ...               ...
# 88402  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 88459  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 88542  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 88599  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 88643  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
#
#       predict_price                            original_title  \
# 43            5,900                      [단종]H 스마트 프레쉬 오일병 1P
# 73           29,970                   VURM 4-bottle wine rack
# 84          138,000                                   그린티 등탁자
# 89           16,900                        [단종] 블루피쉬 극세사 키친매트
# 94           35,800                             스프링 플로어 장 스탠드
# ...             ...                                       ...
# 88402          정보없음             H 에어팟맥스 헤드폰 거치대 알루미늄 스탠드(3색상)
# 88459          정보없음          크리스마스 산타 캔디 하우스 오르골 워터볼 스노우볼 무드등
# 88542          정보없음        우드 현관 마그넷 자석 마스크걸이 3구 Number 후크 3개
# 88599          정보없음  [CPTS] HODGEHOG TOWELING SLIDES 타월링 슬라이드
# 88643          정보없음                   천연 아로마 에센셜 블렌딩 오일 3종 세트
#
#                                          similarity_list  cluster_id  rating_  \
# 43                                                    []        8883      NaN
# 73                                                    []        8906      NaN
# 84                                                    []          10      NaN
# 89                                                    []          13      NaN
# 94     [['스프링 플로 장 스탠드', '스프링 플로 장 스탠드', 1163895, 1.0...          15      NaN
# ...                                                  ...         ...      ...
# 88402                                                 []        1524      NaN
# 88459                                                 []       71942      NaN
# 88542                                                 []       72020      NaN
# 88599                                                 []       72067      NaN
# 88643                                                 []       72101      NaN
#
#        review_ rating_binned
# 43           0    (3.0, 4.0]
# 73           0    (3.0, 4.0]
# 84           0    (3.0, 4.0]
# 89           0    (3.0, 4.0]
# 94           0    (3.0, 4.0]
# ...        ...           ...
# 88402        0    (2.0, 3.0]
# 88459        0    (3.0, 4.0]
# 88542        0    (3.0, 4.0]
# 88599        0    (3.0, 4.0]
# 88643        0    (3.0, 4.0]
#
# [3475 rows x 17 columns]

# %%
item.shape
# Out:
# (55647, 17)

# %%
# 55647개 중에 3475개가 negative_review

# %%
import math
import numpy as np


def get_rating(rating, review):
    if review == 0:
        review = 1
    rating2neg_user = {1:1, 2:1, 3:2, 4:3}
    rating2pos_user = {1:4.5, 2:4.5, 3:4.5, 4:5}
    neg_socre, pos_score = 0, 0
    
    if rating >= 4:
        pos_score = rating2pos_user[4]
        neg_score = rating2neg_user[4]
    elif rating >= 3:
        pos_score = rating2pos_user[3]
        neg_score = rating2neg_user[3]
    elif rating >= 2:
        pos_score = rating2pos_user[2]
        neg_score = rating2neg_user[2]
    elif rating >= 1:
        pos_score = rating2pos_user[2]
        neg_score = rating2neg_user[2]
    else:
        pos_score = rating2pos_user[1]
        neg_score = rating2neg_user[1]
    
    A = np.array([[pos_score, neg_score], [1, 1]])
    B = np.array([rating, review])
    n_pos, n_neg = np.linalg.solve(A, B)

    total_reviews = review
    positve_reviews = n_pos
    review_score = positve_reviews / total_reviews
    rating = round(review_score - (review_score - 0.5) * math.pow(-math.log(total_reviews + 1), 10), 2)
    
    return rating * 100

# %%
ratings = []
for rate, review in zip(item.rating, item.review):
    ratings.append(get_rating(rate, review))

# %%
item["steam_rating"] = ratings

# %%
item.sort_values("steam_rating", inplace=True, ascending=False)

# %%
item.review.max()
# Out:
# 999

# %%
item
# Out:
#           item                  category  rating  review     price  \
# 7407     37307       가구|테이블·식탁·책상|사이드테이블     4.7     999   47,900원
# 81048  1244535        가구|침대|침대+매트리스|수납침대     4.7     999  549,000원
# 37705   350084      데코·식물|플라워·식물|식물|소형식물     4.8     999    8,900원
# 34498   305186             가구|서랍·수납장|수납장     4.6     998   40,000원
# 11727    71771          패브릭|커튼·부자재|가리개커튼     4.6     998       NaN
# ...        ...                       ...     ...     ...       ...
# 59551   742912          가구|침대|침대프레임|일반침대     1.0       1  950,000원
# 5864     28466              가구|진열장·책장|책장     1.0       1       NaN
# 42595   426619              조명|천장등|펜던트조명     1.0       1  205,600원
# 77671  1141971                    조명|벽조명     1.0       1   44,833원
# 40446   394175  가구|테이블·식탁·책상|식탁|식탁·입식테이블     1.0       1  689,000원
#
#                   preprocessed_title   seller discount_rate  \
# 7407                     메이저 사이드 테이블    소프시스            37%
# 81048  올리버 led 조명 단 수납 침대 ss q 매트 포함  오트밀하우스            41%
# 37705  율마 무광 원형 화분 실내 공기 정화 식물 소형 식물   아침향기              1%
# 34498                     지니 원형 수납 단   모노폴리오            45%
# 11727           페르시안 플라워 가리개 커튼 창 커튼     데코뷰            NaN
# ...                              ...      ...           ...
# 59551      수입 프렌지 엔 가구 원목 그레이 퀸 침대 q   리체갤러리            20%
# 5864                           트리 책장    노아가구            NaN
# 42595                   천장 펜던트 clear  글로벤라이팅            29%
# 77671    파스텔 벽등 라운드 리츠 벽 조명 월 램프 마카롱     블레오            39%
# 40446     코지 타원형 1800 식탁 원목 hpm 라미 트   아이엔지홈            47%
#
#                                                    image available_product  \
# 7407   https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 81048  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 37705  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 34498  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 11727  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# ...                                                  ...               ...
# 59551  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 5864   https://image.ohou.se/i/bucketplace-v2-develop...               미입점
# 42595  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 77671  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
# 40446  https://image.ohou.se/i/bucketplace-v2-develop...               NaN
#
#       predict_price                                  original_title  \
# 7407           정보없음                                     메이저 사이드 테이블
# 81048          정보없음  [5%쿠폰] 올리버 LED 조명 3단 수납 침대 SS/Q (매트포함) 4colors
# 37705          정보없음                       율마_무광 원형 화분 실내공기정화식물 소형식물
# 34498          정보없음                                    지니 원형 수납장_2단
# 11727          정보없음                  페르시안 플라워 가리개커튼 (작은창커튼) 2colors
# ...             ...                                             ...
# 59551          정보없음                     수입 프렌지 엔틱가구 원목 미엘 그레이 퀸침대 Q
# 5864         37,900                                            트리책장
# 42595          정보없음                            [해외] 보울 천장 펜던트 clear
# 77671          정보없음                 [해외] 파스텔 벽등 올라운드 플리츠벽조명 월램프 마카롱
# 40446          정보없음                     코지 타원형 1800 식탁 원목 HPM 라미네이트
#
#                                          similarity_list  cluster_id  rating_  \
# 7407                                                  []        1093      NaN
# 81048                                                 []       66346      NaN
# 37705  [['율마 무광 원형 화분 실내 공기 정화 식물 소형 식물', '율마 중형 토분 수...       36369      NaN
# 34498  [['지니 원형 수납 단', '지니 원형 수납 단 단', 66789, 0.90909...        1603      NaN
# 11727                                                 []       17740      NaN
# ...                                                  ...         ...      ...
# 59551  [['수입 프렌지 엔 가구 원목 그레이 퀸 침대 q', '수입 프렌치 엔 가구 원목...        6988      NaN
# 5864                                                  []       13300      NaN
# 42595                                                 []       39570      NaN
# 77671                                                 []       63872      NaN
# 40446                                                 []        5097      NaN
#
#        review_ rating_binned  steam_rating
# 7407         0    (4.0, 5.0]  4.941836e+10
# 81048        0    (4.0, 5.0]  4.941836e+10
# 37705        0    (4.0, 5.0]  4.941712e+10
# 34498        0    (4.0, 5.0]  4.934801e+10
# 11727        0    (4.0, 5.0]  4.934801e+10
# ...        ...           ...           ...
# 59551        0    (0.0, 1.0]  1.000000e+00
# 5864         0    (0.0, 1.0]  1.000000e+00
# 42595        0    (0.0, 1.0]  1.000000e+00
# 77671        0    (0.0, 1.0]  1.000000e+00
# 40446        0    (0.0, 1.0]  1.000000e+00
#
# [55647 rows x 18 columns]

# %%
import pickle

with open("popularity.pickle", "wb") as pkl:
    pickle.dump(list(item[:200].item), pkl)

# %%
import pickle

with open("../gcp/popularity.pickle", "rb") as pkl:
    data = pickle.load(pkl)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# /opt/ml/input/final/EDA/popularity_based_rec.ipynb Cell 27 in <cell line: 3>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bserver_2/opt/ml/input/final/EDA/popularity_based_rec.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import pickle
#       <a href='vscode-notebook-cell://ssh-remote%2Bserver_2/opt/ml/input/final/EDA/popularity_based_rec.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> with open("../gcp/popularity.pickle", "rb") as pkl:
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bserver_2/opt/ml/input/final/EDA/popularity_based_rec.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     data = pickle.load(pkl)
#
# EOFError: Ran out of input

# %%
len(data)
# Out:
# 200

# %%
type(data[6])
# Out:
# int
